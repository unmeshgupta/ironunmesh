# %% [markdown]
# ## TOC:
# * [Destination for the holiday](#Destination)
# * [ Traveller going for Holiday](#Traveller)
# * [ Person interests of the traveller](#Details)
# * [ Video snapshot of travelling destination](#Destination)

# %% [markdown]
# # Destination <a name="Destination"></a>

# %% [markdown]
# ##### Sushant *loves* doing staycaytion. In his upcoming travels, he plans to goes to an exotic island off the <span style="color:red">Strait of Malacca</span>.

# %% [markdown]
# # Traveller  <a name="Traveller"></a>

# %%
name = input("Please enter the person's name: ")
# Out:
# Please enter the person's name:

# %% [markdown]
# ![l82220220121110238.webp](attachment:l82220220121110238.webp)

# %% [markdown]
# # Details <a name="Details"></a>

# %% [markdown]
# #### He will be travelling to an archipelago called <span style="color:blue">Andaman & Nicobar Islands </span>.
#
# - The islands are also famously known as the erstwhile colonial jailpost of British India, with the Celllular Jail located here. Despite its dark history, the islands are now a tourist place. Also being a history nerd, decision to go to these islands was natural to Sushant
#
#
# - He would also explore adrenaline activites here like snorkelling, scuba-diving.
#
#
# - Coincidentaly, the islands are also known for being a military base for Indian Air Force. Having a an army father, Sushant would also like to go to one of these post for a tour.

# %% [markdown]
# # A tourism video of Andaman & Nicobar Islands <a name="Destination"></a>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("https://www.youtube.com/watch?v=q43hYTqNFXc", width=400)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=q43hYTqNFXc"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
jupyter nbconvert --to slides --no-input presentation.ipynb
# Out:
#   File "<ipython-input-30-302b2754c7ef>", line 1
#     jupyter nbconvert --to slides --no-input presentation.ipynb
#             ^
# SyntaxError: invalid syntax
